# %%
print(2011-3276)
# Out:
# -1265

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r'water_potability.csv')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
df = df.dropna().reset_index(drop=True)
df
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.417441     8.059332  356.886136
# 1      9.092223  181.101509  17978.986339     6.546600  310.135738
# 2      5.584087  188.313324  28748.687739     7.544869  326.678363
# 3     10.223862  248.071735  28749.716544     7.513408  393.663396
# 4      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 2006   8.989900  215.047358  15921.412018     6.297312  312.931022
# 2007   6.702547  207.321086  17246.920347     7.708117  304.510230
# 2008  11.491011   94.812545  37188.826022     9.263166  258.930600
# 2009   6.069616  186.659040  26138.780191     7.747547  345.700257
# 2010   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       363.266516       18.436524       100.341674   4.628771           0
# ...

# %%
#df.count('Potability'==1)
dff = df[df['Potability'] == 0]
dff
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.417441     8.059332  356.886136
# 1      9.092223  181.101509  17978.986339     6.546600  310.135738
# 2      5.584087  188.313324  28748.687739     7.544869  326.678363
# 3     10.223862  248.071735  28749.716544     7.513408  393.663396
# 4      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 1905  11.449739  186.652648  12355.344107     7.065576  321.831513
# 1906   6.283679  205.376624  19905.436548     7.078345  284.206021
# 1907   6.971577  185.906938  27959.987873     7.214510  349.743879
# 1908   4.709187  179.141018  22291.418577     6.774276  407.417977
# 1909   5.230003  176.714023  27971.891806     7.597981  413.914001
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       363.266516       18.436524       100.341674   4.628771           0
# ...

# %%
#df.count('Potability'==1)
dff = df[df['Potability'] == 1]
dff
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 154    9.445130  145.805402  13168.529156     9.444471  310.583374
# 155    9.024845  128.096691  19859.676476     8.016423  300.150377
# 156    6.800119  242.008082  39143.403329     9.501695  187.170714
# 157    7.174135  203.408935  20401.102461     7.681806  287.085679
# 158    7.657991  236.960889  14245.789121     6.289065  373.165363
# ...         ...         ...           ...          ...         ...
# 2006   8.989900  215.047358  15921.412018     6.297312  312.931022
# 2007   6.702547  207.321086  17246.920347     7.708117  304.510230
# 2008  11.491011   94.812545  37188.826022     9.263166  258.930600
# 2009   6.069616  186.659040  26138.780191     7.747547  345.700257
# 2010   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 154     592.659021        8.606397        77.577460   3.875165           1
# ...

# %%
df = df[['ph','Hardness','Solids','Chloramines', 'Potability']]
df.head()
# Out:
#           ph    Hardness        Solids  Chloramines  Potability
# 0   8.316766  214.373394  22018.417441     8.059332           0
# 1   9.092223  181.101509  17978.986339     6.546600           0
# 2   5.584087  188.313324  28748.687739     7.544869           0
# 3  10.223862  248.071735  28749.716544     7.513408           0
# 4   8.635849  203.361523  13672.091764     4.563009           0

# %%
df.tail()
# Out:
#              ph    Hardness        Solids  Chloramines  Potability
# 2006   8.989900  215.047358  15921.412018     6.297312           1
# 2007   6.702547  207.321086  17246.920347     7.708117           1
# 2008  11.491011   94.812545  37188.826022     9.263166           1
# 2009   6.069616  186.659040  26138.780191     7.747547           1
# 2010   4.668102  193.681735  47580.991603     7.166639           1

# %%
df.mean()
# Out:
# ph                 7.085990
# Hardness         195.968072
# Solids         21917.441374
# Chloramines        7.134338
# Potability         0.403282
# dtype: float64

# %%
df.mode()
# Out:
#              ph    Hardness        Solids  Chloramines  Potability
# 0      0.227499   73.492234    320.942611     1.390871         0.0
# 1      0.989912   77.459586   1198.943699     1.920271         NaN
# 2      1.431782   81.710895   1351.906979     2.397985         NaN
# 3      1.757037   94.091307   1372.091043     2.456014         NaN
# 4      1.985383   94.812545   2552.962804     2.458609         NaN
# ...         ...         ...           ...          ...         ...
# 2006  11.568768  286.567991  50793.898917    12.580026         NaN
# 2007  11.898078  287.975540  53735.899194    12.626900         NaN
# 2008  12.246928  300.292476  55334.702799    12.653362         NaN
# 2009  13.349889  306.627481  56351.396304    13.043806         NaN
# 2010  14.000000  317.338124  56488.672413    13.127000         NaN
#
# [2011 rows x 5 columns]

# %%
df.median()
# Out:
# ph                 7.027297
# Hardness         197.191839
# Solids         20933.512750
# Chloramines        7.143907
# Potability         0.000000
# dtype: float64

# %%
df.var()
# Out:
# ph             2.475388e+00
# Hardness       1.065049e+03
# Solids         7.468831e+07
# Chloramines    2.511654e+00
# Potability     2.407653e-01
# dtype: float64

# %%
print(1.573337**2)
# Out:
# 2.475389315569

# %%
df.describe(percentiles=[0.2, 0.5, 0.7])
# Out:
#                 ph     Hardness        Solids  Chloramines   Potability
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441374     7.134338     0.403282
# std       1.573337    32.635085   8642.239815     1.584820     0.490678
# min       0.227499    73.492234    320.942611     1.390871     0.000000
# 20%       5.841119   170.132446  14450.175747     5.899676     0.000000
# 50%       7.027297   197.191839  20933.512750     7.143907     0.000000
# 70%       7.830608   211.783235  25780.059077     7.872038     1.000000
# max      14.000000   317.338124  56488.672413    13.127000     1.000000

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines   Potability
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441374     7.134338     0.403282
# std       1.573337    32.635085   8642.239815     1.584820     0.490678
# min       0.227499    73.492234    320.942611     1.390871     0.000000
# 25%       6.089723   176.744938  15615.665390     6.138895     0.000000
# 50%       7.027297   197.191839  20933.512750     7.143907     0.000000
# 75%       8.052969   216.441070  27182.587067     8.109726     1.000000
# max      14.000000   317.338124  56488.672413    13.127000     1.000000

# %%
df.var()
# Out:
# ph             2.475388e+00
# Hardness       1.065049e+03
# Solids         7.468831e+07
# Chloramines    2.511654e+00
# Potability     2.407653e-01
# dtype: float64

# %%
#Gráfico Boxplot
sns.set(style="whitegrid")
sns.boxplot(x='Potability', y='ph',data=df)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='ph'>

# %%
#Gráfico Boxplot
sns.set(style="whitegrid")
sns.boxplot(x='Potability', y='Hardness',data=df)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Hardness'>

# %%
#Gráfico Boxplot
sns.set(style="whitegrid")
sns.boxplot(x='Potability', y='Solids',data=df)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Solids'>

# %%
#Gráfico Boxplot
sns.set(style="whitegrid")
sns.boxplot(x='Potability', y='Chloramines',data=df)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Chloramines'>

# %%
plt.hist(x = df['ph'])
# Out:
# (array([  3.,  11.,  70., 286., 680., 603., 264.,  82.,  10.,   2.]),
#  array([ 0.22749905,  1.60474915,  2.98199924,  4.35924934,  5.73649943,
#          7.11374953,  8.49099962,  9.86824972, 11.24549981, 12.62274991,
#         14.        ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x = df['Hardness'])
# Out:
# (array([  7.,  32.,  88., 288., 539., 624., 309.,  80.,  41.,   3.]),
#  array([ 73.49223369,  97.87682273, 122.26141176, 146.6460008 ,
#         171.03058984, 195.41517887, 219.79976791, 244.18435695,
#         268.56894598, 292.95353502, 317.33812406]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x = df['Solids'])
# Out:
# (array([ 20., 167., 467., 508., 431., 229., 119.,  51.,  15.,   4.]),
#  array([  320.94261127,  5937.71559142, 11554.48857157, 17171.26155171,
#         22788.03453186, 28404.80751201, 34021.58049215, 39638.3534723 ,
#         45255.12645245, 50871.89943259, 56488.67241274]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x = df['Chloramines'])
# Out:
# (array([  7.,  42.,  93., 337., 578., 574., 255.,  98.,  18.,   9.]),
#  array([ 1.3908709 ,  2.56448381,  3.73809672,  4.91170963,  6.08532254,
#          7.25893545,  8.43254836,  9.60616127, 10.77977418, 11.95338709,
#         13.127     ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure()
sns.pairplot(df, hue = 'Potability', height=3, markers=["o","s"])
plt.savefig('img.png', format='png')
plt.show()

# %%
plt.figure()
sns.pairplot(df, height=3)
plt.savefig('img2.png', format='png')
plt.show()

# %%
df.cov()
# Out:
#                       ph      Hardness        Solids  Chloramines  Potability
# ph              2.475388      5.594047 -1.191314e+03    -0.061759    0.011217
# Hardness        5.594047   1065.048742 -1.502397e+04    -1.173283   -0.024100
# Solids      -1191.314479 -15023.968352  7.468831e+07  -709.323403  172.481345
# Chloramines    -0.061759     -1.173283 -7.093234e+02     2.511654    0.016162
# Potability      0.011217     -0.024100  1.724813e+02     0.016162    0.240765

# %%
df.corr()
# Out:
#                    ph  Hardness    Solids  Chloramines  Potability
# ph           1.000000  0.108948 -0.087615    -0.024768    0.014530
# Hardness     0.108948  1.000000 -0.053269    -0.022685   -0.001505
# Solids      -0.087615 -0.053269  1.000000    -0.051789    0.040674
# Chloramines -0.024768 -0.022685 -0.051789     1.000000    0.020784
# Potability   0.014530 -0.001505  0.040674     0.020784    1.000000
